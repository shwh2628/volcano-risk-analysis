# %% [markdown]
# # Sample Notebook

# %%
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt

import rasterio as rio
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es

# %%
os.getcwd()
# Out:
# '/Users/shannonwhite'

# %%
os.chdir('/Users/shannonwhite')

# %%
with rio.open('/Users/shannonwhite/Downloads/hi_hi_1992_2001_ccap_change/hi_hi_1992_2001_ccap_change.img') as src:
    landuse = src.read()
    landuse_meta = src.meta

# %%
landuse.shape
# Out:
# (1, 5190, 4571)

# %%
landuse=np.squeeze(landuse)

# %%
fig, ax = plt.subplots()
ax.imshow(landuse)
ax.set(title="XX")
plt.show()

# %%
with rio.open('/Users/shannonwhite/Downloads/201805_Volcano_Kilauea_HI_WORLDVIEW_NGA.xml') as src1:
    kilauea = src1.read()
    kilauea_meta = src1.meta
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/Users/shannonwhite/Downloads/201805_Volcano_Kilauea_HI_WORLDVIEW_NGA.xml' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-20-c5ce7adc2db2> in <module>()
# ----> 1 with rio.open('/Users/shannonwhite/Downloads/201805_Volcano_Kilauea_HI_WORLDVIEW_NGA.xml') as src1:
#       2     kilauea = src1.read()
#       3     kilauea_meta = src1.meta
#
# ~/anaconda3/envs/earth-analytics-python/lib/python3.6/site-packages/rasterio/env.py in wrapper(*args, **kwds)
# ...

# %%
with rio.open('/Users/shannonwhite/Downloads/L1C_T05QKB_A007762_20180831T205929*.tif') as src2:
    s02_post = src2.read()
    s02_post_meta = src2.meta

# %%
s02_post.shape
# Out:
# (3, 5490, 5490)

# %%
fig, ax = plt.subplots()
ax.imshow(s02_post[0])
ax.set(title="Sentinel 2 Post eruption 8/31/2018")
plt.show()

# %%
s02_ndvi = (s02_post[7] - s02_post[3]) / (s02_post[7] + s02_post[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-4a8571336c47> in <module>()
# ----> 1 s02_ndvi = (s02_post[7] - s02_post[3]) / (s02_post[7] + s02_post[3])
#
# IndexError: index 7 is out of bounds for axis 0 with size 3

# %%
with rio.open('/Users/shannonwhite/Downloads/LC080620472018051401T1-SC20190225153920/LC08_L1TP_062047_20180514_20180604_01_T1_sr_band1.tif') as src4:
    kilauea2 = src4.read()
    kilauea2_meta = src4.meta
